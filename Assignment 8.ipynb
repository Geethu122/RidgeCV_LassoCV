# %%
import pandas as pd
data = pd.read_excel(r"E:\Clustering\Clustering\EastWestAirlines.xlsx",sheet_name  = 'data')
data.head(10)
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
# 5    6    16420           0          1          1          1            0
# 6    7    84914           0          3          1          1        27482
# 7    8    20856           0          1          1          1         5250
# 8    9   443003           0          3          2          1         1753
# 9   10   104860           0          3          1          1        28426
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
# 5            0                  0                0               6942       0
# 6           25                  0                0               6994       0
# 7            4                250                1               6938       1
# 8           43               3850               12               6948       1
# 9           28               1150                3               6931       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %% [markdown]
# # the dataset have only (int)

# %%
data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (15,5))
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data['Balance'].value_counts()
# Out:
# Balance
# 1000     10
# 500       5
# 2000      5
# 1500      4
# 5000      3
#          ..
# 9554      1
# 30130     1
# 12665     1
# 9860      1
# 3016      1
# Name: count, Length: 3904, dtype: int64

# %%
data['Qual_miles'].value_counts()
# Out:
# Qual_miles
# 0       3773
# 1000      17
# 500       15
# 967        4
# 888        4
#         ...
# 4116       1
# 1388       1
# 1896       1
# 3692       1
# 1005       1
# Name: count, Length: 164, dtype: int64

# %%
def remove_outliers(df):
  numerical_columns = df.select_dtypes(include = ['int64']).columns

  for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    Upper_limit = Q3 + (1.5 * IQR)
    Lower_limit = Q1 - (1.5 * IQR)

    df = df[(df[col] >= Lower_limit) & (df[col] <= Upper_limit)]
  return df

data_new = remove_outliers(data)
data_new
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3990  4013    11310           0          1          1          1         5021
# 3991  4014    39142           0          3          1          1        14981
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 5               0                  0                0               6942
# ...           ...                ...              ...                ...
# 3990            2                  0                0               1409
# 3991           28                  0                0               1408
# 3992           12                  0                0               1407
# 3993            3                  0                0               1397
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 5          0
# ...      ...
# 3990       0
# 3991       0
# 3992       0
# 3993       0
# 3998       0
#
# [1785 rows x 12 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (15,6))
sns.boxplot(data_new)
# Out:
# <Axes: >

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaled_data = StandardScaler()
df = scaled_data.fit_transform(data_new)
df
# Out:
# array([[-1.8920833 , -0.35172951,  0.        , ...,  0.        ,
#          1.56649934,  0.        ],
#        [-1.89123029, -0.57351045,  0.        , ...,  0.        ,
#          1.5511899 ,  0.        ],
#        [-1.89037728, -0.02248486,  0.        , ...,  0.        ,
#          1.58276562,  0.        ],
#        ...,
#        [ 1.53191714, -0.7744566 ,  0.        , ...,  0.        ,
#         -1.1093033 ,  0.        ],
#        [ 1.53277016, -0.95406951,  0.        , ...,  0.        ,
#         -1.1140875 ,  0.        ],
#        [ 1.53703523, -0.9779448 ,  0.        , ...,  0.        ,
#         -1.11360908,  0.        ]])

# %%
new_df = pd.DataFrame(df,columns = ['ID#',	'Balance'	,'Qual_miles',	'cc1_miles',	'cc2_miles',	'cc3_miles',	'Bonus_miles','Bonus_trans'	,'Flight_miles_12mo'	,'Flight_trans_12',	'Days_since_enroll',	'Award?'])
new_df
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.892083 -0.351730         0.0  -0.571271        0.0        0.0
# 1    -1.891230 -0.573510         0.0  -0.571271        0.0        0.0
# 2    -1.890377 -0.022485         0.0  -0.571271        0.0        0.0
# 3    -1.889524 -0.684862         0.0  -0.571271        0.0        0.0
# 4    -1.887818 -0.643890         0.0  -0.571271        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 1780  1.530211 -0.771242         0.0  -0.571271        0.0        0.0
# 1781  1.531064 -0.077612         0.0   1.522607        0.0        0.0
# 1782  1.531917 -0.774457         0.0  -0.571271        0.0        0.0
# 1783  1.532770 -0.954070         0.0  -0.571271        0.0        0.0
# 1784  1.537035 -0.977945         0.0  -0.571271        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0       -0.663819    -0.922006                0.0              0.0
# 1       -0.659907    -0.784064                0.0              0.0
# 2       -0.287037    -0.508181                0.0              0.0
# 3       -0.632715    -0.922006                0.0              0.0
# 4       -0.680421    -1.059947                0.0              0.0
# ...           ...          ...                ...              ...
# 1780    -0.201357    -0.784064                0.0              0.0
# 1781     0.748946     2.802415                0.0              0.0
# 1782    -0.591783     0.595351                0.0              0.0
# 1783    -0.645595    -0.646123                0.0              0.0
# 1784    -0.680421    -1.059947                0.0              0.0
#
#       Days_since_enroll  Award?
# 0              1.566499     0.0
# 1              1.551190     0.0
# 2              1.582766     0.0
# 3              1.543535     0.0
# 4              1.538751     0.0
# ...                 ...     ...
# 1780          -1.108346     0.0
# 1781          -1.108825     0.0
# 1782          -1.109303     0.0
# 1783          -1.114087     0.0
# 1784          -1.113609     0.0
#
# [1785 rows x 12 columns]

# %%
plt.figure(figsize = (15,5))
sns.boxplot(new_df)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.pairplot(new_df)
# Out:
# C:\Users\ravik\Downloads\dekstop\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
new_df.corr()
# Out:
#                         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID#                1.000000 -0.249524         NaN  -0.177044        NaN
# Balance           -0.249524  1.000000         NaN   0.586241        NaN
# Qual_miles              NaN       NaN         NaN        NaN        NaN
# cc1_miles         -0.177044  0.586241         NaN   1.000000        NaN
# cc2_miles               NaN       NaN         NaN        NaN        NaN
# cc3_miles               NaN       NaN         NaN        NaN        NaN
# Bonus_miles       -0.140135  0.580243         NaN   0.892161        NaN
# Bonus_trans       -0.088499  0.432786         NaN   0.581852        NaN
# Flight_miles_12mo       NaN       NaN         NaN        NaN        NaN
# Flight_trans_12         NaN       NaN         NaN        NaN        NaN
# Days_since_enroll -0.963140  0.271885         NaN   0.183133        NaN
# Award?                  NaN       NaN         NaN        NaN        NaN
#
#                    cc3_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# ID#                      NaN    -0.140135    -0.088499                NaN
# Balance                  NaN     0.580243     0.432786                NaN
# Qual_miles               NaN          NaN          NaN                NaN
# cc1_miles                NaN     0.892161     0.581852                NaN
# cc2_miles                NaN          NaN          NaN                NaN
# cc3_miles                NaN          NaN          NaN                NaN
# Bonus_miles              NaN     1.000000     0.604022                NaN
# Bonus_trans              NaN     0.604022     1.000000                NaN
# Flight_miles_12mo        NaN          NaN          NaN                NaN
# Flight_trans_12          NaN          NaN          NaN                NaN
# Days_since_enroll        NaN     0.145044     0.102708                NaN
# Award?                   NaN          NaN          NaN                NaN
#
#                    Flight_trans_12  Days_since_enroll  Award?
# ID#                            NaN          -0.963140     NaN
# Balance                        NaN           0.271885     NaN
# Qual_miles                     NaN                NaN     NaN
# cc1_miles                      NaN           0.183133     NaN
# cc2_miles                      NaN                NaN     NaN
# cc3_miles                      NaN                NaN     NaN
# Bonus_miles                    NaN           0.145044     NaN
# Bonus_trans                    NaN           0.102708     NaN
# Flight_miles_12mo              NaN                NaN     NaN
# Flight_trans_12                NaN                NaN     NaN
# Days_since_enroll              NaN           1.000000     NaN
# Award?                         NaN                NaN     NaN

# %%
new_df.hist(bins = 15 , figsize = (15,10))
# Out:
# array([[<Axes: title={'center': 'ID#'}>,
#         <Axes: title={'center': 'Balance'}>,
#         <Axes: title={'center': 'Qual_miles'}>],
#        [<Axes: title={'center': 'cc1_miles'}>,
#         <Axes: title={'center': 'cc2_miles'}>,
#         <Axes: title={'center': 'cc3_miles'}>],
#        [<Axes: title={'center': 'Bonus_miles'}>,
#         <Axes: title={'center': 'Bonus_trans'}>,
#         <Axes: title={'center': 'Flight_miles_12mo'}>],
#        [<Axes: title={'center': 'Flight_trans_12'}>,
#         <Axes: title={'center': 'Days_since_enroll'}>,
#         <Axes: title={'center': 'Award?'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15,5))
sns.boxplot(new_df)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID#                1.000000 -0.243737   -0.019374  -0.224465   0.020291
# Balance           -0.243737  1.000000    0.108722   0.338344  -0.008804
# Qual_miles        -0.019374  0.108722    1.000000   0.007931  -0.013923
# cc1_miles         -0.224465  0.338344    0.007931   1.000000  -0.068223
# cc2_miles          0.020291 -0.008804   -0.013923  -0.068223   1.000000
# cc3_miles         -0.014707  0.035243   -0.007779   0.060555  -0.006166
# Bonus_miles       -0.203012  0.403487    0.031021   0.825200  -0.003969
# Bonus_trans       -0.146915  0.324935    0.050725   0.608943   0.064399
# Flight_miles_12mo -0.031013  0.217551    0.126774   0.037370   0.010598
# Flight_trans_12   -0.052096  0.255700    0.144004   0.041333   0.028284
# Days_since_enroll -0.964988  0.263129    0.017312   0.230849  -0.005807
# Award?            -0.177901  0.178494    0.095256   0.335457   0.005332
#
#                    cc3_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# ID#                -0.014707    -0.203012    -0.146915          -0.031013
# Balance             0.035243     0.403487     0.324935           0.217551
# Qual_miles         -0.007779     0.031021     0.050725           0.126774
# cc1_miles           0.060555     0.825200     0.608943           0.037370
# cc2_miles          -0.006166    -0.003969     0.064399           0.010598
# cc3_miles           1.000000     0.204134     0.097313          -0.001777
# Bonus_miles         0.204134     1.000000     0.603180           0.183536
# Bonus_trans         0.097313     0.603180     1.000000           0.377216
# Flight_miles_12mo  -0.001777     0.183536     0.377216           1.000000
# Flight_trans_12    -0.001117     0.185261     0.432364           0.869193
# Days_since_enroll   0.010832     0.210397     0.161262           0.037271
# Award?              0.023484     0.373506     0.333893           0.217715
#
#                    Flight_trans_12  Days_since_enroll    Award?
# ID#                      -0.052096          -0.964988 -0.177901
# Balance                   0.255700           0.263129  0.178494
# Qual_miles                0.144004           0.017312  0.095256
# cc1_miles                 0.041333           0.230849  0.335457
# cc2_miles                 0.028284          -0.005807  0.005332
# cc3_miles                -0.001117           0.010832  0.023484
# Bonus_miles               0.185261           0.210397  0.373506
# Bonus_trans               0.432364           0.161262  0.333893
# Flight_miles_12mo         0.869193           0.037271  0.217715
# Flight_trans_12           1.000000           0.059260  0.247909
# Days_since_enroll         0.059260           1.000000  0.188121
# Award?                    0.247909           0.188121  1.000000

# %%
#correlation
corr_matrix = data.corr()
sns.heatmap(corr_matrix,annot = True,cmap = 'coolwarm',fmt= '.2f')
# Out:
# <Axes: >

# %%
#correlation
corr_matrix = new_df.corr()
sns.heatmap(corr_matrix,annot = True,cmap = 'coolwarm',fmt= '.2f')
# Out:
# <Axes: >

# %% [markdown]
# # Implementing Clustering algorithms

# %%
import scipy.cluster.hierarchy as sch
#plt.figure(figsize = (15,5))
dendo = sch.dendrogram(sch.linkage(new_df ,method = 'complete'))

# %%
from sklearn.cluster import AgglomerativeClustering
HC = AgglomerativeClustering(n_clusters=4, metric='euclidean', linkage='complete')
HC
# Out:
# AgglomerativeClustering(linkage='complete', metric='euclidean', n_clusters=4)

# %%
y_hc = HC.fit_predict(new_df)
y_hc
# Out:
# array([3, 3, 3, ..., 1, 1, 1], dtype=int64)

# %%
data_new['h_clustered'] = y_hc
data_new
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3990  4013    11310           0          1          1          1         5021
# 3991  4014    39142           0          3          1          1        14981
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 5               0                  0                0               6942
# ...           ...                ...              ...                ...
# 3990            2                  0                0               1409
# 3991           28                  0                0               1408
# 3992           12                  0                0               1407
# 3993            3                  0                0               1397
# 3998            0                  0                0               1398
#
#       Award?  h_clustered
# 0          0            3
# 1          0            3
# 2          0            3
# 3          0            3
# 5          0            3
# ...      ...          ...
# 3990       0            1
# 3991       0            1
# 3992       0            1
# 3993       0            1
# 3998       0            1
#
# [1785 rows x 13 columns]

# %%
data_new[data_new['h_clustered'] == 0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 30      31   177926           0          3          1          1        20797
# 110    113   181019           0          3          1          1        18415
# 116    119   143967           0          2          1          1         7346
# 195    199   134601           0          1          1          1            0
# 224    228   193976           0          3          1          1        10849
# ...    ...      ...         ...        ...        ...        ...          ...
# 3299  3322   140914           0          1          1          1            0
# 3421  3444   139982           0          1          1          1        14500
# 3836  3859   130595           0          1          1          1            0
# 3892  3915   134882           0          3          1          1        15717
# 3949  3972   170632           0          1          1          1         4650
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 30             13                  0                0               7886
# 110            15                  0                0               7714
# 116            11                  0                0               7689
# 195             0                  0                0               7493
# 224            14                  0                0               7416
# ...           ...                ...              ...                ...
# 3299            0                  0                0               1791
# 3421            6                  0                0               1430
# 3836            0                  0                0               1677
# 3892           14                  0                0               1597
# 3949            3                  0                0               1480
#
#       Award?  h_clustered
# 30         0            0
# 110        0            0
# 116        0            0
# 195        0            0
# 224        0            0
# ...      ...          ...
# 3299       0            0
# 3421       0            0
# 3836       0            0
# 3892       0            0
# 3949       0            0
#
# [65 rows x 13 columns]

# %%
data_new[data_new['h_clustered']==1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 1092  1104    19960           0          1          1          1            0
# 1129  1141     1625           0          1          1          1         1375
# 1142  1154     8516           0          1          1          1            0
# 1179  1191    34450           0          1          1          1        26996
# 1189  1201     6584           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3990  4013    11310           0          1          1          1         5021
# 3991  4014    39142           0          3          1          1        14981
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 1092            0                  0                0               4896
# 1129            4                  0                0               1547
# 1142            0                  0                0               5566
# 1179            7                  0                0               5566
# 1189            0                  0                0               5118
# ...           ...                ...              ...                ...
# 3990            2                  0                0               1409
# 3991           28                  0                0               1408
# 3992           12                  0                0               1407
# 3993            3                  0                0               1397
# 3998            0                  0                0               1398
#
#       Award?  h_clustered
# 1092       0            1
# 1129       0            1
# 1142       0            1
# 1179       0            1
# 1189       0            1
# ...      ...          ...
# 3990       0            1
# 3991       0            1
# 3992       0            1
# 3993       0            1
# 3998       0            1
#
# [985 rows x 13 columns]

# %%
data_new[data_new['h_clustered'] == 2]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 6        7    84914           0          3          1          1        27482
# 44      45   121260           0          3          1          1        18493
# 56      57    75971           0          4          1          1        34339
# 58      59    38077           0          3          1          1        34024
# 60      61   134457           0          3          1          1        15588
# ...    ...      ...         ...        ...        ...        ...          ...
# 3899  3922    90666           0          4          1          1        32474
# 3945  3968    62645           0          1          1          1        19602
# 3948  3971    35509           0          3          1          1        14204
# 3966  3989    91605           0          4          1          1        37840
# 3985  4008    59017           0          4          1          1        34746
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 6              25                  0                0               6994
# 44             18                  0                0               7808
# 56             14                  0                0               6869
# 58              8                  0                0               6837
# 60             14                  0                0               6861
# ...           ...                ...              ...                ...
# 3899           14                  0                0               1582
# 3945           11                  0                0               1474
# 3948           13                  0                0               1486
# 3966           18                  0                0               1444
# 3985           25                  0                0               1418
#
#       Award?  h_clustered
# 6          0            2
# 44         0            2
# 56         0            2
# 58         0            2
# 60         0            2
# ...      ...          ...
# 3899       0            2
# 3945       0            2
# 3948       0            2
# 3966       0            2
# 3985       0            2
#
# [315 rows x 13 columns]

# %%
data_new[data_new['h_clustered'] == 3]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 2335  2353    40420           0          2          1          1         8649
# 2361  2379    23139           0          2          1          1         8156
# 2370  2388    17920           0          1          1          1         3250
# 2382  2400    14075           0          1          1          1         4286
# 2485  2504    23649           0          1          1          1         3250
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 5               0                  0                0               6942
# ...           ...                ...              ...                ...
# 2335           14                  0                0               3651
# 2361           14                  0                0               3578
# 2370           18                  0                0               3546
# 2382           15                  0                0               3513
# 2485           16                  0                0               3176
#
#       Award?  h_clustered
# 0          0            3
# 1          0            3
# 2          0            3
# 3          0            3
# 5          0            3
# ...      ...          ...
# 2335       0            3
# 2361       0            3
# 2370       0            3
# 2382       0            3
# 2485       0            3
#
# [420 rows x 13 columns]

# %%
data_new.groupby('h_clustered').mean()
# Out:
#                      ID#        Balance  Qual_miles  cc1_miles  cc2_miles  \
# h_clustered
# 0            1906.615385  153853.846154         0.0   1.830769        1.0
# 1            2898.784772   24612.648731         0.0   1.065990        1.0
# 2            1963.066667   83034.219048         0.0   3.311111        1.0
# 3             865.521429   35779.988095         0.0   1.302381        1.0
#
#              cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# h_clustered
# 0                  1.0   9764.215385    11.600000                0.0
# 1                  1.0   2374.742132     5.017259                0.0
# 2                  1.0  25800.676190    15.422222                0.0
# 3                  1.0   3877.476190     7.528571                0.0
#
#              Flight_trans_12  Days_since_enroll  Award?
# h_clustered
# 0                        0.0        4406.430769     0.0
# 1                        0.0        2514.531980     0.0
# 2                        0.0        4190.615873     0.0
# 3                        0.0        6112.059524     0.0

# %%
data_new['h_clustered'].mean()
# Out:
# 1.6106442577030813

# %% [markdown]
# # k-means Clustering

# %% [markdown]
# # Elbow chart

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#wcss (within cluster sum of squares)
wcss = []
for i in range(1,10):
  kmeans = KMeans(n_clusters = i , random_state = 0 )
  kmeans.fit(new_df)
  wcss.append(kmeans.inertia_) #inertia = variance
print(wcss)
plt.plot(range(1,10),wcss)
# Out:
# [10710.000000000004, 6591.161426043799, 4582.430763858255, 3917.582002299929, 3457.9128355361236, 3087.5217802111047, 2784.569722516929, 2531.759498036152, 2330.685584443662]

# %%
k_cluster= KMeans(n_clusters = 4 , random_state = 0)
kmc = k_cluster.fit(new_df)
kmc
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
y_kmc = kmc.fit_predict(new_df)
y_kmc
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
data_new['k_clustered'] = y_kmc

# %%
data_new
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3990  4013    11310           0          1          1          1         5021
# 3991  4014    39142           0          3          1          1        14981
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 5               0                  0                0               6942
# ...           ...                ...              ...                ...
# 3990            2                  0                0               1409
# 3991           28                  0                0               1408
# 3992           12                  0                0               1407
# 3993            3                  0                0               1397
# 3998            0                  0                0               1398
#
#       Award?  h_clustered  k_clustered
# 0          0            3            2
# 1          0            3            2
# 2          0            3            2
# 3          0            3            2
# 5          0            3            2
# ...      ...          ...          ...
# 3990       0            1            0
# 3991       0            1            3
# 3992       0            1            0
# 3993       0            1            0
# 3998       0            1            0
#
# [1785 rows x 14 columns]

# %% [markdown]
# # DB Scan

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps = 3 , min_samples =4)
dbscan.fit(new_df)
# Out:
# DBSCAN(eps=3, min_samples=4)

# %%
y_dbscan = dbscan.fit_predict(new_df)
y_dbscan
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
data_new['dbs_clustered'] = y_dbscan

# %%
data_new
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3990  4013    11310           0          1          1          1         5021
# 3991  4014    39142           0          3          1          1        14981
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 5               0                  0                0               6942
# ...           ...                ...              ...                ...
# 3990            2                  0                0               1409
# 3991           28                  0                0               1408
# 3992           12                  0                0               1407
# 3993            3                  0                0               1397
# 3998            0                  0                0               1398
#
#       Award?  h_clustered  k_clustered  dbs_clustered
# 0          0            3            2              0
# 1          0            3            2              0
# 2          0            3            2              0
# 3          0            3            2              0
# 5          0            3            2              0
# ...      ...          ...          ...            ...
# 3990       0            1            0              0
# 3991       0            1            3              0
# 3992       0            1            0              0
# 3993       0            1            0              0
# 3998       0            1            0              0
#
# [1785 rows x 15 columns]

# %%
data_new['h_clustered'].value_counts()
# Out:
# h_clustered
# 1    985
# 3    420
# 2    315
# 0     65
# Name: count, dtype: int64

# %%
data_new['k_clustered'].value_counts()
# Out:
# k_clustered
# 0    599
# 2    561
# 1    325
# 3    300
# Name: count, dtype: int64

# %%
data_new['dbs_clustered'].value_counts()
# Out:
# dbs_clustered
# 0    1785
# Name: count, dtype: int64

# %%
from sklearn import metrics
from sklearn.metrics import silhouette_score
hc_s_c = metrics.silhouette_score(new_df, y_hc)
hc_s_c
# Out:
# 0.3205127561111654

# %%
kmc_s_c = metrics.silhouette_score(new_df, y_kmc)
kmc_s_c
# Out:
# 0.3417589662216043

# %%
import seaborn as sns
sns.scatterplot(data = data_new , x = 'Balance' ,y = 'Bonus_miles' , hue = 'h_clustered' , style = 'h_clustered', size = "h_clustered")
# Out:
# <Axes: xlabel='Balance', ylabel='Bonus_miles'>

# %%
import seaborn as sns
sns.scatterplot(data = data_new , x = 'Balance' ,y = 'Bonus_miles' , hue = 'k_clustered' , style = 'k_clustered', size = "k_clustered",palette = 'Set3')
# Out:
# <Axes: xlabel='Balance', ylabel='Bonus_miles'>

# %%
import seaborn as sns
sns.scatterplot(data = data_new , x = 'Balance' ,y = 'Bonus_miles' , hue = 'dbs_clustered' , style = 'dbs_clustered', size = "dbs_clustered" , palette = 'deep')
# Out:
# <Axes: xlabel='Balance', ylabel='Bonus_miles'>

# %%
sns.heatmap(data_new)
# Out:
# <Axes: >
